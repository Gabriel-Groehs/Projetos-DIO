# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriel-Groehs/Projetos-DIO/blob/main/redu_o_de_dimensionalidade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image

# %%
imagem_colorida = Image.open('hear_him_easter_campaign.jpeg')

# %%
imagem_cinza = imagem_colorida.convert('L')

# %%
imagem_pb = imagem_colorida.convert('1')

# %%
imagem_cinza.save('cinza.jpg')
imagem_pb.save('pb.jpg')

# %%
imagem_colorida
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7F8B1FD6F850>

# %%
imagem_cinza
# Out:
# <PIL.Image.Image image mode=L size=1280x720 at 0x7F8B1FD6F5B0>

# %%
imagem_pb
# Out:
# <PIL.Image.Image image mode=1 size=1280x720 at 0x7F8B1FD6F1C0>
